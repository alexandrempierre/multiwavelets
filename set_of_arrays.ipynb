# %%
from collections import namedtuple
#
import numpy as np


SquareSubmatrix = namedtuple('SquareSubmatrix', ('index', 'size'))

# %%
n = 2**3
M = np.array([
    [r * 10 + c for c in range(n)] for r in range(n)
])
M
# Out:
# array([[ 0,  1,  2,  3,  4,  5,  6,  7],
#        [10, 11, 12, 13, 14, 15, 16, 17],
#        [20, 21, 22, 23, 24, 25, 26, 27],
#        [30, 31, 32, 33, 34, 35, 36, 37],
#        [40, 41, 42, 43, 44, 45, 46, 47],
#        [50, 51, 52, 53, 54, 55, 56, 57],
#        [60, 61, 62, 63, 64, 65, 66, 67],
#        [70, 71, 72, 73, 74, 75, 76, 77]])

# %%
id_M = id(M)
S02 = SquareSubmatrix(0, 2)
M[S02.index:S02.index + S02.size, S02.index:S02.index + S02.size]
# Out:
# array([[ 0,  1],
#        [10, 11]])
